# %%
import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
google_api_key = os.getenv('GOOGLE_API_KEY')

# %%
if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

# %%
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# %%
user_prompt = [
    {"role": "user", "content": "Tell a models-capablity for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=user_prompt)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemma-4-31b-it", messages=user_prompt)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="llama3.2:1b", messages=user_prompt)
display(Markdown(response.choices[0].message.content))
